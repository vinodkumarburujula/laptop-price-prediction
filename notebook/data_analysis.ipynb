# %%
#shell 1
import pandas as pd

df = pd.read_csv("../dataset/laptop_data.csv")
df.head()
# Out:
#     Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size    Weight  \
# 0    Asus         3.830296        16               512    11.185147  2.641094
# 1    Acer         2.912833         4              1000    11.311372  3.260012
# 2  Lenovo         3.241627         4               256    11.853023  2.029061
# 3    Acer         3.806248        16               512    12.280360  4.573865
# 4    Acer         3.268097        32              1000    14.990877  4.193472
#
#           Price
# 0  17395.093065
# 1  31607.605919
# 2   9291.023542
# 3  17436.728334
# 4  32917.990718

# %%
#shell 2
df = df[['Brand', 'RAM_Size', 'Storage_Capacity', 'Price']]
df.head()
# Out:
#     Brand  RAM_Size  Storage_Capacity         Price
# 0    Asus        16               512  17395.093065
# 1    Acer         4              1000  31607.605919
# 2  Lenovo         4               256   9291.023542
# 3    Acer        16               512  17436.728334
# 4    Acer        32              1000  32917.990718

# %%
#shll 3
df_encoded = pd.get_dummies(df, columns=['Brand'], drop_first=True)

# %%
#shell 4
X = df_encoded.drop('Price', axis=1)
y = df_encoded['Price']

# %%
#shell 5

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
#shell 6

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %%
#shell 7
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#shell 8
from sklearn.metrics import r2_score

y_pred = lr.predict(X_test)
r2_score(y_test, y_pred)
# Out:
# 0.9993776342169363

# %%
#shell 9
import pickle

pickle.dump(lr, open("../model/laptop_model.pkl", "wb"))
pickle.dump(scaler, open("../model/scaler.pkl", "wb"))

# %%
#shell 10

X.columns
# Out:
# Index(['RAM_Size', 'Storage_Capacity', 'Brand_Asus', 'Brand_Dell', 'Brand_HP',
#        'Brand_Lenovo'],
#       dtype='object')
